# %%
# import libraries
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
# read csv list of all adrs
df = pd.read_csv("asianADRS.csv")

# %%
# drop irrelevant column
df.drop(columns='Unnamed: 0')
# Out:
#    Symbol                                            Name      Country  \
# 0     TSM  Taiwan Semiconductor Manufacturing Co Ltd ADRs       Taiwan
# 1      TM                          Toyota Motor Corp ADRs        Japan
# 2    SONY                     Sony Group Corporation ADRs        Japan
# 3    MUFG        Mitsubishi UFJ Financial Group Inc. ADRs        Japan
# 4     TAK      Takeda Pharmaceutical Company Limited ADRs        Japan
# 5     HMC                         Honda Motor Co Ltd ADRs        Japan
# 6    SMFG        Sumitomo Mitsui Financial Group Inc ADRs        Japan
# 7     MFG                 Mizuho Financial Group Inc ADRs        Japan
# 8    BGNE                                    BeiGene ADRs        China
# 9     CAJ                                  Canon Inc ADRs        Japan
# 10    CHT                    Chunghwa Telecom Co Ltd ADRs       Taiwan
# 11    PKX                                      POSCO ADRs  South Korea
# 12    TLK    Telekomunikasi Indonesia Persero Tbk PT ADRs    Indonesia
# 13    UMC               United Microelectronics Corp ADRs       Taiwan
# 14     IX                                       Orix ADRs        Japan
# 15     KB                     KB Financial Group Inc ADRs  South Korea
# 16    SKM                          SK Telecom Co Ltd ADRs  South Korea
# 17    ASX     Advanced Semiconductor Engineering Inc ADRs       Taiwan
# 18    NMR                        Nomura Holdings Inc ADRs        Japan
# 19    SHG             Shinhan Financial Group Co Ltd ADRs  South Korea
# 20    LFC                China Life Insurance Co Ltd ADRs        China
# 21    SNP            China Petroleum & Chemical Corp ADRs        China
# 22    KEP                  Korea Electric Power Corp ADRs  South Korea
# 23    MBT                    Mobile TeleSystems PJSC ADRs       Russia
# 24    PTR                          PetroChina Co Ltd ADRs        China
# 25    LPL                          LG Display Co Ltd ADRs  South Korea
# 26     WF                 Woori Financial Group Inc. ADRs  South Korea
# 27     KT                                    KT Corp ADRs  South Korea
# 28    ZNH                    China Southern Airlines ADRs        China
# 29    CEA                     China Eastern Airlines ADRs        China
# 30    ACH              Aluminum Corporation of China ADRs        China
# 31    HNP            Huaneng Power International Inc ADRs        China
# 32   IMOS                       ChipMOS TECHNOLOGIES ADRs       Taiwan
# 33    SHI             Sinopec Shanghai Petrochemical ADRs        China
#
#    Underlying Symbol            Underlying Exchange        Market cap
# 0            TT:2330          Taiwan Stock Exchange  $647,222,296,282
# 1            JT:7203           Tokyo Stock Exchange  $251,511,846,683
# 2            JT:6758           Tokyo Stock Exchange  $134,756,741,338
# 3            JT:8306           Tokyo Stock Exchange   $74,293,513,306
# 4            JT:4502           Tokyo Stock Exchange   $58,767,219,290
# 5            JT:7267           Tokyo Stock Exchange   $54,469,652,890
# 6            JT:8316           Tokyo Stock Exchange   $49,434,176,016
# 7            JT:8411           Tokyo Stock Exchange   $37,073,048,461
# 8            HK:6160             Hong Kong Exchange   $31,342,405,037
# 9            JT:7751           Tokyo Stock Exchange   $30,529,845,691
# 10           TT:2412          Taiwan Stock Exchange   $30,354,888,350
# 11         KP:005490  Korea Exchange (Stock Market)   $24,963,334,597
# 12           IJ:TLKM       Indonesia Stock Exchange   $23,388,589,339
# 13           TT:2303          Taiwan Stock Exchange   $23,009,838,260
# 14           JT:8591           Tokyo Stock Exchange   $21,661,886,039
# 15         KP:105560  Korea Exchange (Stock Market)   $20,095,996,774
# 16         KP:017670  Korea Exchange (Stock Market)   $19,991,830,586
# 17           TT:3711          Taiwan Stock Exchange   $17,337,443,860
# 18           JT:8604           Tokyo Stock Exchange   $17,331,895,541
# 19         KP:055550  Korea Exchange (Stock Market)   $17,016,789,309
# 20           HK:2628             Hong Kong Exchange   $15,522,291,050
# 21           HK:0386             Hong Kong Exchange   $13,705,819,216
# 22         KP:015760  Korea Exchange (Stock Market)   $13,352,852,802
# 23           RX:MTSS        Standard-Classica-Forts    $8,213,348,277
# 24           HK:0857             Hong Kong Exchange    $7,705,318,280
# 25         KP:034220  Korea Exchange (Stock Market)    $7,170,626,628
# 26         KP:316140  Korea Exchange (Stock Market)    $6,524,484,727
# 27         KP:030200  Korea Exchange (Stock Market)    $6,517,350,728
# 28           HK:1055             Hong Kong Exchange    $3,123,420,827
# 29           HK:0670             Hong Kong Exchange    $2,439,297,699
# 30           HK:2600             Hong Kong Exchange    $1,672,241,573
# 31           HK:0902             Hong Kong Exchange    $1,666,285,929
# 32           TT:8150          Taiwan Stock Exchange    $1,150,857,490
# 33           HK:0338             Hong Kong Exchange      $824,820,000

# %%
# All ADR tickers and underlying stock tickers
tickers = ['TSM', 'TM', 'SONY', 'MUFG', 'TAK', 'HMC', 'SMFG', 'MFG','BGNE', 'CAJ', 'CHT', 'PKX', 'TLK', 'UMC',
           'IX', 'KB', 'SKM','ASX', 'NMR', 'SHG', 'LFC', 'SNP', 'KEP', 'MBT', 'PTR', 'LPL', 'WF', 'KT', 'ZNH', 
           'CEA', 'ACH', 'HNP', 'IMOS', 'SHI',
           '2330.TW', '7203.T', '6758.T', '8306.T', '4502.T', '7267.T','8316.T', '8411.T', '6160.HK', 
           '7751.T', '2412.TW', '005490.KS', 'TLKM.JK', '2303.TW', '8591.T', '105560.KS', '017670.KS',
           '3711.TW', '8604.T', '055550.KS', '2628.HK', '0386.HK', '015760.KS', 'MTSS.ME', '0857.HK', 
           '034220.KS', '316140.KS','030200.KS', '1055.HK', '0670.HK','2600.HK', '0902.HK', '8150.TW','0338.HK']

# %%
# fetch data and save as csv file
for ticker in tickers:
    df =  pdr.get_data_yahoo(symbols=ticker, start=datetime(2016, 1, 1), end=datetime(2021, 1, 1))
    df.to_csv(ticker+'.csv')
