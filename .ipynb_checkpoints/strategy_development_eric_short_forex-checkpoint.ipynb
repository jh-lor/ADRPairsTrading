# %%
#from ib_insync import *
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join
from helpers import *
from strategies import *

# %%
mypath = 'eric_jh_data/'
countries = sorted(['Australia', 'Japan', 'China'])
fx_dict = {'Australia':('eric_jh_data/Forex/AUD_USD_new.csv',0),
           'Japan':('eric_jh_data/Forex/USD_JPY_new.csv',1),
           'China':('eric_jh_data/Forex/USD_HKD_new.csv',1)}

list_pairs = []
for country in countries:
    countrypath = mypath + country
    adr_names =  [f for f in listdir(countrypath) if not isfile(join(countrypath, f))] #grab all adr names of the country
    for adr in sorted(adr_names):
        list_pairs.append((country, adr))

# %%
# Store ratios
for (country, adr) in list_pairs:
    ratio_geq_1, ratio = get_ratio(country, adr, fx_dict)
    if adr == "ACH_2600" or adr == "BGNE_6160":
        rounded_ratio = float('%.2g' % ratio)
    else:
        rounded_ratio = float('%.1g' % ratio)
    print("Country: {}, ADR_Stock: {}, Estimated Ratio (4 d.p.): {}, Implied Ratio (2 s.f.): {}".format(country, adr, ratio, rounded_ratio))
    ratio_df = pd.DataFrame({"ratio_geq_1" : [ratio_geq_1], "ratio" : [rounded_ratio]})
    ratio_df.to_csv(f'eric_jh_data/{country}/{adr}/ratio.csv')
# Out:
# Country: Australia, ADR_Stock: ATHE_ATH, Estimated Ratio (4 d.p.): 59.4889, Implied Ratio (2 s.f.): 60.0
# Country: Australia, ADR_Stock: GENE_GTG, Estimated Ratio (4 d.p.): 595.5978, Implied Ratio (2 s.f.): 600.0
# Country: Australia, ADR_Stock: IMMP_IMM, Estimated Ratio (4 d.p.): 9.9082, Implied Ratio (2 s.f.): 10.0
# Country: Australia, ADR_Stock: IMRN_IMC, Estimated Ratio (4 d.p.): 39.4289, Implied Ratio (2 s.f.): 40.0
# Country: Australia, ADR_Stock: JHX_JHX, Estimated Ratio (4 d.p.): 1.0043, Implied Ratio (2 s.f.): 1.0
# Country: Australia, ADR_Stock: KZIA_KZA, Estimated Ratio (4 d.p.): 10.0346, Implied Ratio (2 s.f.): 10.0
# Country: Australia, ADR_Stock: MESO_MSB, Estimated Ratio (4 d.p.): 5.0155, Implied Ratio (2 s.f.): 5.0
# Country: Australia, ADR_Stock: PLL_PLL, Estimated Ratio (4 d.p.): 101.5788, Implied Ratio (2 s.f.): 100.0
# Country: Australia, ADR_Stock: WBK_WBC, Estimated Ratio (4 d.p.): 0.9997, Implied Ratio (2 s.f.): 1.0
# Country: China, ADR_Stock: ACH_2600, Estimated Ratio (4 d.p.): 24.9288, Implied Ratio (2 s.f.): 25.0
# Country: China, ADR_Stock: BGNE_6160, Estimated Ratio (4 d.p.): 12.9902, Implied Ratio (2 s.f.): 13.0
# Country: China, ADR_Stock: CEA_670, Estimated Ratio (4 d.p.): 49.9009, Implied Ratio (2 s.f.): 50.0
# Country: China, ADR_Stock: HNP_902, Estimated Ratio (4 d.p.): 39.8606, Implied Ratio (2 s.f.): 40.0
# Country: China, ADR_Stock: LFC_2628, Estimated Ratio (4 d.p.): 4.9939, Implied Ratio (2 s.f.): 5.0
# Country: China, ADR_Stock: PTR_857, Estimated Ratio (4 d.p.): 99.8525, Implied Ratio (2 s.f.): 100.0
# Country: China, ADR_Stock: SHI_338, Estimated Ratio (4 d.p.): 99.9224, Implied Ratio (2 s.f.): 100.0
# Country: China, ADR_Stock: SNP_386, Estimated Ratio (4 d.p.): 99.9663, Implied Ratio (2 s.f.): 100.0
# Country: China, ADR_Stock: ZNH_1055, Estimated Ratio (4 d.p.): 49.8338, Implied Ratio (2 s.f.): 50.0
# Country: Japan, ADR_Stock: CAJ_7751, Estimated Ratio (4 d.p.): 0.9995, Implied Ratio (2 s.f.): 1.0
# Country: Japan, ADR_Stock: HMC_7267, Estimated Ratio (4 d.p.): 0.9999, Implied Ratio (2 s.f.): 1.0
# Country: Japan, ADR_Stock: IX_8591, Estimated Ratio (4 d.p.): 5.0055, Implied Ratio (2 s.f.): 5.0
# Country: Japan, ADR_Stock: MFG_8411, Estimated Ratio (4 d.p.): 4.9999, Implied Ratio (2 s.f.): 5.0
# Country: Japan, ADR_Stock: MUFG_8306, Estimated Ratio (4 d.p.): 0.9995, Implied Ratio (2 s.f.): 1.0
# Country: Japan, ADR_Stock: NMR_8604, Estimated Ratio (4 d.p.): 0.9998, Implied Ratio (2 s.f.): 1.0
# Country: Japan, ADR_Stock: SMFG_8316, Estimated Ratio (4 d.p.): 5.0032, Implied Ratio (2 s.f.): 5.0
# Country: Japan, ADR_Stock: SONY_6758, Estimated Ratio (4 d.p.): 1.0009, Implied Ratio (2 s.f.): 1.0
# Country: Japan, ADR_Stock: TAK_4502, Estimated Ratio (4 d.p.): 2.001, Implied Ratio (2 s.f.): 2.0
# Country: Japan, ADR_Stock: TM_7203, Estimated Ratio (4 d.p.): 2.0001, Implied Ratio (2 s.f.): 2.0

# %% [markdown]
# This shows the empircally estimated ratio, and the implied ratio we shall assume.
# These values corroborate with the select few we checked online, like GENE_GTG and BGNE_6160.

# %%
# date - date in local time
# All dates are in local time: so in sequential order (for each row), it will go stock_open, stock_close, adr_open, adr_close
# avg_bid_non_us_before - how much foreign currency we can buy with 1 USD, 1 minute before the Asian market opens
# avg_ask_non_us_before - how much foreign currency we would need to sell for 1 USD, 1 minute before the Asian market opens
# avg_non_us_before - average of avg_bid_non_us_before and avg_ask_non_us_before
# avg_bid_non_us_at - how much foreign currency we can buy with 1 USD, when the Asian market opens
# avg_ask_non_us_at - how much foreign currency we would need to sell for 1 USD, when the Asian market opens
# avg_non_us_at - average of avg_bid_non_us_at and avg_ask_non_us_at
# avg_bid_us_before - how much foreign currency we can buy with 1 USD, 1 minute before the US market opens
# avg_ask_us_before - how much foreign currency we would need to sell for 1 USD, 1 minute before the US market opens
# avg_us_before - average of avg_bid_us_before and avg_ask_us_before
# avg_bid_us_at - how much foreign currency we can buy with 1 USD, when the US market opens
# avg_ask_us_at - how much foreign currency we would need to sell for 1 USD, when the US market opens
# avg_us_at - average of avg_bid_us_at and avg_ask_us_at
# ir - foreign interest rate
# stock_num_per_unit - how many stocks we would buy for 1 "unit" of trade
# adr_num_per_unit - how many adr shares we would sell for 1 "unit" of trade

merged_df = data_processing(*list_pairs[1], fx_dict)
merged_df.head()
# Out:
#          date  adr_open  adr_close  adr_volume  stock_open  stock_close  \
# 0  2015-04-10     18.08      17.36        1873       0.040        0.039
# 1  2015-04-13     17.76      16.16        2762       0.039        0.039
# 2  2015-04-14     16.96      17.08        2545       0.036        0.038
# 3  2015-04-15     17.68      17.52        2106       0.039        0.038
# 4  2015-04-16     17.40      17.00        1068       0.038        0.036
#
#    stock_volume  avg_bid_non_us_before  avg_ask_non_us_before  \
# 0        987003               1.296948               1.299612
# 1       1586945               1.303310               1.305987
# 2       2905099               1.316900               1.319606
# 3       2069419               1.312108               1.314822
# 4       2378678               1.301459               1.304133
#
#    avg_non_us_before  ...  avg_bid_us_at  avg_ask_us_at  avg_us_at  ir  \
# 0           1.298280  ...       1.302409       1.305068   1.303738 NaN
# 1           1.304648  ...       1.315530       1.318215   1.316872 NaN
# 2           1.318253  ...       1.309820       1.312529   1.311174 NaN
# 3           1.313465  ...       1.310301       1.312994   1.311647 NaN
# 4           1.302796  ...       1.282035       1.284634   1.283335 NaN
#
#    stock_num_per_unit  adr_num_per_unit  stock_open_per_unit  \
# 0               600.0                 1                 24.0
# 1               600.0                 1                 23.4
# 2               600.0                 1                 21.6
# 3               600.0                 1                 23.4
# 4               600.0                 1                 22.8
#
#    stock_close_per_unit  adr_open_per_unit  adr_close_per_unit
# 0                  23.4              18.08               17.36
# 1                  23.4              17.76               16.16
# 2                  22.8              16.96               17.08
# 3                  22.8              17.68               17.52
# 4                  21.6              17.40               17.00
#
# [5 rows x 26 columns]

# %%
last_dates, last_portfolio_values = report_and_store_statistics(pairs_trade_v1, 'logs1.txt', list_pairs, fx_dict)
plot_returns(last_dates, last_portfolio_values)
# Out:
# Country: Australia, ADR_Stock: ATHE_ATH, Return: 0.15%, Hit Ratio: 88.64%, Max Drawdown: 0.03%
# Country: Australia, ADR_Stock: GENE_GTG, Return: 2.18%, Hit Ratio: 81.13%, Max Drawdown: 1.94%
# Country: Australia, ADR_Stock: IMMP_IMM, Return: 0.53%, Hit Ratio: 75.0%, Max Drawdown: 0.18%
# Country: Australia, ADR_Stock: IMRN_IMC, Return: 1.07%, Hit Ratio: 83.78%, Max Drawdown: 0.02%
# Country: Australia, ADR_Stock: JHX_JHX, Return: -0.18%, Hit Ratio: 38.61%, Max Drawdown: 0.19%
# Country: Australia, ADR_Stock: KZIA_KZA, Return: 0.38%, Hit Ratio: 73.24%, Max Drawdown: 0.55%
# Country: Australia, ADR_Stock: MESO_MSB, Return: 0.33%, Hit Ratio: 70.15%, Max Drawdown: 3.44%
# Country: Australia, ADR_Stock: PLL_PLL, Return: 20.02%, Hit Ratio: 71.15%, Max Drawdown: 7.32%
# Country: Australia, ADR_Stock: WBK_WBC, Return: -0.68%, Hit Ratio: 42.55%, Max Drawdown: 1.5%
# Country: China, ADR_Stock: ACH_2600, Return: 0.15%, Hit Ratio: 49.41%, Max Drawdown: 0.1%
# Country: China, ADR_Stock: BGNE_6160, Return: 36.79%, Hit Ratio: 83.33%, Max Drawdown: 2.2%
# Country: China, ADR_Stock: CEA_670, Return: 0.39%, Hit Ratio: 56.41%, Max Drawdown: 0.12%
# Country: China, ADR_Stock: HNP_902, Return: 0.31%, Hit Ratio: 44.59%, Max Drawdown: 0.21%
# Country: China, ADR_Stock: LFC_2628, Return: -1.6%, Hit Ratio: 37.25%, Max Drawdown: 3.25%
# Country: China, ADR_Stock: PTR_857, Return: -1.31%, Hit Ratio: 50.86%, Max Drawdown: 2.4%
# Country: China, ADR_Stock: SHI_338, Return: 0.49%, Hit Ratio: 57.32%, Max Drawdown: 0.07%
# Country: China, ADR_Stock: SNP_386, Return: -0.22%, Hit Ratio: 47.57%, Max Drawdown: 2.15%
# Country: China, ADR_Stock: ZNH_1055, Return: -0.16%, Hit Ratio: 55.79%, Max Drawdown: 0.57%
# Country: Japan, ADR_Stock: CAJ_7751, Return: -3.24%, Hit Ratio: 42.39%, Max Drawdown: 4.01%
# Country: Japan, ADR_Stock: HMC_7267, Return: -6.35%, Hit Ratio: 41.96%, Max Drawdown: 8.94%
# Country: Japan, ADR_Stock: IX_8591, Return: -0.91%, Hit Ratio: 38.0%, Max Drawdown: 1.42%
# Country: Japan, ADR_Stock: MFG_8411, Return: -0.45%, Hit Ratio: 33.71%, Max Drawdown: 0.52%
# Country: Japan, ADR_Stock: MUFG_8306, Return: -1.8%, Hit Ratio: 48.94%, Max Drawdown: 2.5%
# Country: Japan, ADR_Stock: NMR_8604, Return: -0.72%, Hit Ratio: 37.93%, Max Drawdown: 0.89%
# Country: Japan, ADR_Stock: SMFG_8316, Return: -6.0%, Hit Ratio: 35.35%, Max Drawdown: 6.63%
# Country: Japan, ADR_Stock: SONY_6758, Return: -25.18%, Hit Ratio: 43.01%, Max Drawdown: 28.48%
# Country: Japan, ADR_Stock: TAK_4502, Return: 0.72%, Hit Ratio: 34.78%, Max Drawdown: 2.87%
# Country: Japan, ADR_Stock: TM_7203, Return: -8.77%, Hit Ratio: 42.19%, Max Drawdown: 8.93%

# %%
last_dates, last_portfolio_values = report_and_store_statistics(pairs_trade_v2, 'logs2.txt', list_pairs, fx_dict)
plot_returns(last_dates, last_portfolio_values)
# Out:
# Country: Australia, ADR_Stock: ATHE_ATH, Return: 0.19%, Hit Ratio: 82.61%, Max Drawdown: 0.02%
# Country: Australia, ADR_Stock: GENE_GTG, Return: 2.81%, Hit Ratio: 79.73%, Max Drawdown: 0.38%
# Country: Australia, ADR_Stock: IMMP_IMM, Return: 0.99%, Hit Ratio: 82.93%, Max Drawdown: 1.01%
# Country: Australia, ADR_Stock: IMRN_IMC, Return: 0.06%, Hit Ratio: 80.0%, Max Drawdown: 0.01%
# Country: Australia, ADR_Stock: JHX_JHX, Return: 0.14%, Hit Ratio: 48.39%, Max Drawdown: 0.05%
# Country: Australia, ADR_Stock: KZIA_KZA, Return: 0.24%, Hit Ratio: 72.88%, Max Drawdown: 0.37%
# Country: Australia, ADR_Stock: MESO_MSB, Return: 2.19%, Hit Ratio: 76.19%, Max Drawdown: 2.93%
# Country: Australia, ADR_Stock: PLL_PLL, Return: 8.04%, Hit Ratio: 80.0%, Max Drawdown: 3.99%
# Country: Australia, ADR_Stock: WBK_WBC, Return: 0.75%, Hit Ratio: 51.04%, Max Drawdown: 0.99%
# Country: China, ADR_Stock: ACH_2600, Return: 0.15%, Hit Ratio: 53.04%, Max Drawdown: 0.16%
# Country: China, ADR_Stock: BGNE_6160, Return: 4.46%, Hit Ratio: 52.63%, Max Drawdown: 7.54%
# Country: China, ADR_Stock: CEA_670, Return: 0.25%, Hit Ratio: 60.68%, Max Drawdown: 0.05%
# Country: China, ADR_Stock: HNP_902, Return: 0.44%, Hit Ratio: 58.33%, Max Drawdown: 0.07%
# Country: China, ADR_Stock: LFC_2628, Return: -1.03%, Hit Ratio: 50.46%, Max Drawdown: 2.02%
# Country: China, ADR_Stock: PTR_857, Return: -1.41%, Hit Ratio: 57.28%, Max Drawdown: 1.72%
# Country: China, ADR_Stock: SHI_338, Return: -0.11%, Hit Ratio: 51.28%, Max Drawdown: 0.38%
# Country: China, ADR_Stock: SNP_386, Return: 3.61%, Hit Ratio: 61.54%, Max Drawdown: 0.81%
# Country: China, ADR_Stock: ZNH_1055, Return: 0.43%, Hit Ratio: 60.0%, Max Drawdown: 0.17%
# Country: Japan, ADR_Stock: CAJ_7751, Return: -0.1%, Hit Ratio: 40.74%, Max Drawdown: 2.31%
# Country: Japan, ADR_Stock: HMC_7267, Return: -0.57%, Hit Ratio: 42.28%, Max Drawdown: 3.67%
# Country: Japan, ADR_Stock: IX_8591, Return: 0.54%, Hit Ratio: 47.22%, Max Drawdown: 0.48%
# Country: Japan, ADR_Stock: MFG_8411, Return: 0.33%, Hit Ratio: 56.98%, Max Drawdown: 0.16%
# Country: Japan, ADR_Stock: MUFG_8306, Return: 0.17%, Hit Ratio: 50.96%, Max Drawdown: 1.1%
# Country: Japan, ADR_Stock: NMR_8604, Return: 0.27%, Hit Ratio: 47.96%, Max Drawdown: 0.37%
# Country: Japan, ADR_Stock: SMFG_8316, Return: 2.12%, Hit Ratio: 56.7%, Max Drawdown: 1.8%
# Country: Japan, ADR_Stock: SONY_6758, Return: 6.43%, Hit Ratio: 53.72%, Max Drawdown: 10.8%
# Country: Japan, ADR_Stock: TAK_4502, Return: 11.07%, Hit Ratio: 47.12%, Max Drawdown: 1.85%
# Country: Japan, ADR_Stock: TM_7203, Return: -1.98%, Hit Ratio: 46.61%, Max Drawdown: 3.77%

# %%
last_dates, last_portfolio_values = report_and_store_statistics(pairs_trade_v3a, 'logs3a.txt', list_pairs, fx_dict)
plot_returns(last_dates, last_portfolio_values)
# Out:
# Country: Australia, ADR_Stock: ATHE_ATH, Return: 0.2%, Hit Ratio: 85.0%, Max Drawdown: 0.03%
# Country: Australia, ADR_Stock: GENE_GTG, Return: 3.71%, Hit Ratio: 79.07%, Max Drawdown: 1.92%
# Country: Australia, ADR_Stock: IMMP_IMM, Return: 1.33%, Hit Ratio: 75.44%, Max Drawdown: 0.15%
# Country: Australia, ADR_Stock: IMRN_IMC, Return: 1.1%, Hit Ratio: 80.0%, Max Drawdown: 0.02%
# Country: Australia, ADR_Stock: JHX_JHX, Return: 0.22%, Hit Ratio: 44.16%, Max Drawdown: 0.09%
# Country: Australia, ADR_Stock: KZIA_KZA, Return: 0.85%, Hit Ratio: 69.57%, Max Drawdown: 0.36%
# Country: Australia, ADR_Stock: MESO_MSB, Return: 2.21%, Hit Ratio: 82.91%, Max Drawdown: 2.67%
# Country: Australia, ADR_Stock: PLL_PLL, Return: 16.35%, Hit Ratio: 75.76%, Max Drawdown: 3.72%
# Country: Australia, ADR_Stock: WBK_WBC, Return: -0.22%, Hit Ratio: 47.71%, Max Drawdown: 1.73%
# Country: China, ADR_Stock: ACH_2600, Return: 0.08%, Hit Ratio: 52.07%, Max Drawdown: 0.17%
# Country: China, ADR_Stock: BGNE_6160, Return: 21.88%, Hit Ratio: 66.67%, Max Drawdown: 5.34%
# Country: China, ADR_Stock: CEA_670, Return: 0.18%, Hit Ratio: 55.92%, Max Drawdown: 0.13%
# Country: China, ADR_Stock: HNP_902, Return: 0.63%, Hit Ratio: 53.68%, Max Drawdown: 0.12%
# Country: China, ADR_Stock: LFC_2628, Return: -3.09%, Hit Ratio: 45.45%, Max Drawdown: 4.31%
# Country: China, ADR_Stock: PTR_857, Return: -3.45%, Hit Ratio: 49.43%, Max Drawdown: 4.19%
# Country: China, ADR_Stock: SHI_338, Return: 0.16%, Hit Ratio: 52.35%, Max Drawdown: 0.37%
# Country: China, ADR_Stock: SNP_386, Return: 1.15%, Hit Ratio: 53.67%, Max Drawdown: 2.12%
# Country: China, ADR_Stock: ZNH_1055, Return: 0.25%, Hit Ratio: 55.88%, Max Drawdown: 0.32%
# Country: Japan, ADR_Stock: CAJ_7751, Return: -2.26%, Hit Ratio: 41.14%, Max Drawdown: 4.06%
# Country: Japan, ADR_Stock: HMC_7267, Return: -9.0%, Hit Ratio: 41.67%, Max Drawdown: 9.58%
# Country: Japan, ADR_Stock: IX_8591, Return: 0.2%, Hit Ratio: 41.21%, Max Drawdown: 0.71%
# Country: Japan, ADR_Stock: MFG_8411, Return: 0.03%, Hit Ratio: 48.87%, Max Drawdown: 0.36%
# Country: Japan, ADR_Stock: MUFG_8306, Return: -1.44%, Hit Ratio: 48.21%, Max Drawdown: 2.58%
# Country: Japan, ADR_Stock: NMR_8604, Return: 0.02%, Hit Ratio: 49.34%, Max Drawdown: 0.64%
# Country: Japan, ADR_Stock: SMFG_8316, Return: -3.59%, Hit Ratio: 46.79%, Max Drawdown: 5.11%
# Country: Japan, ADR_Stock: SONY_6758, Return: -26.89%, Hit Ratio: 46.11%, Max Drawdown: 30.48%
# Country: Japan, ADR_Stock: TAK_4502, Return: 11.84%, Hit Ratio: 41.14%, Max Drawdown: 2.09%
# Country: Japan, ADR_Stock: TM_7203, Return: -14.87%, Hit Ratio: 41.62%, Max Drawdown: 15.12%

# %%
last_dates, last_portfolio_values = report_and_store_statistics(pairs_trade_v3b, 'logs3b.txt', list_pairs, fx_dict)
plot_returns(last_dates, last_portfolio_values)
# Out:
# Country: Australia, ADR_Stock: ATHE_ATH, Return: 0.15%, Hit Ratio: 87.72%, Max Drawdown: 0.03%
# Country: Australia, ADR_Stock: GENE_GTG, Return: 3.68%, Hit Ratio: 82.5%, Max Drawdown: 1.93%
# Country: Australia, ADR_Stock: IMMP_IMM, Return: 0.93%, Hit Ratio: 75.0%, Max Drawdown: 0.1%
# Country: Australia, ADR_Stock: IMRN_IMC, Return: 1.13%, Hit Ratio: 80.43%, Max Drawdown: 0.02%
# Country: Australia, ADR_Stock: JHX_JHX, Return: 0.13%, Hit Ratio: 43.05%, Max Drawdown: 0.15%
# Country: Australia, ADR_Stock: KZIA_KZA, Return: 1.75%, Hit Ratio: 70.79%, Max Drawdown: 0.07%
# Country: Australia, ADR_Stock: MESO_MSB, Return: 2.26%, Hit Ratio: 80.83%, Max Drawdown: 2.66%
# Country: Australia, ADR_Stock: PLL_PLL, Return: 22.56%, Hit Ratio: 72.31%, Max Drawdown: 5.26%
# Country: Australia, ADR_Stock: WBK_WBC, Return: 0.6%, Hit Ratio: 48.91%, Max Drawdown: 1.06%
# Country: China, ADR_Stock: ACH_2600, Return: -0.19%, Hit Ratio: 52.17%, Max Drawdown: 0.37%
# Country: China, ADR_Stock: BGNE_6160, Return: 27.66%, Hit Ratio: 67.74%, Max Drawdown: 6.26%
# Country: China, ADR_Stock: CEA_670, Return: 0.07%, Hit Ratio: 53.5%, Max Drawdown: 0.22%
# Country: China, ADR_Stock: HNP_902, Return: 0.66%, Hit Ratio: 58.28%, Max Drawdown: 0.09%
# Country: China, ADR_Stock: LFC_2628, Return: -1.88%, Hit Ratio: 46.3%, Max Drawdown: 2.39%
# Country: China, ADR_Stock: PTR_857, Return: -3.46%, Hit Ratio: 48.54%, Max Drawdown: 4.16%
# Country: China, ADR_Stock: SHI_338, Return: 0.16%, Hit Ratio: 50.89%, Max Drawdown: 0.24%
# Country: China, ADR_Stock: SNP_386, Return: 0.47%, Hit Ratio: 54.71%, Max Drawdown: 2.28%
# Country: China, ADR_Stock: ZNH_1055, Return: -0.79%, Hit Ratio: 54.43%, Max Drawdown: 0.91%
# Country: Japan, ADR_Stock: CAJ_7751, Return: -2.14%, Hit Ratio: 40.83%, Max Drawdown: 3.58%
# Country: Japan, ADR_Stock: HMC_7267, Return: -9.3%, Hit Ratio: 40.43%, Max Drawdown: 9.87%
# Country: Japan, ADR_Stock: IX_8591, Return: 0.48%, Hit Ratio: 40.74%, Max Drawdown: 0.67%
# Country: Japan, ADR_Stock: MFG_8411, Return: 0.01%, Hit Ratio: 47.29%, Max Drawdown: 0.37%
# Country: Japan, ADR_Stock: MUFG_8306, Return: -2.24%, Hit Ratio: 45.93%, Max Drawdown: 3.86%
# Country: Japan, ADR_Stock: NMR_8604, Return: -0.44%, Hit Ratio: 47.4%, Max Drawdown: 0.66%
# Country: Japan, ADR_Stock: SMFG_8316, Return: -4.49%, Hit Ratio: 45.34%, Max Drawdown: 5.19%
# Country: Japan, ADR_Stock: SONY_6758, Return: -21.87%, Hit Ratio: 47.54%, Max Drawdown: 27.63%
# Country: Japan, ADR_Stock: TAK_4502, Return: 12.08%, Hit Ratio: 43.95%, Max Drawdown: 4.46%
# Country: Japan, ADR_Stock: TM_7203, Return: -15.08%, Hit Ratio: 43.68%, Max Drawdown: 15.36%
