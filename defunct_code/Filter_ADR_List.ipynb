# %%
import pandas as pd

# %%
# Out:
#     Symbol                                        Name    Country  \
# 107    JHX                James Hardie Industries ADRs  Australia
# 403   GENE                   Genetic Technologies ADRs  Australia
# 362   KZIA                     Kazia Therapeutics ADRs  Australia
# 350   IMMP                        Immutep Limited ADRs  Australia
# 252    PLL               Piedmont Lithium Limited ADRs  Australia
# 251   MESO                              Mesoblast ADRs  Australia
# 409   ATHE          Alterity Therapeutics Limited ADRs  Australia
# 424   IMRN                        Immuron Limited ADRs  Australia
# 32     WBK                   Westpac Banking Corp ADRs  Australia
# 205    CEA                 China Eastern Airlines ADRs      China
# 72    BGNE                                BeiGene ADRs      China
# 104    LFC            China Life Insurance Co Ltd ADRs      China
# 112    SNP        China Petroleum & Chemical Corp ADRs      China
# ...
