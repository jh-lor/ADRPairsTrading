# %%
import numpy as np
import pandas as pd

# %%
# Source csv obtained from https://stockmarketmba.com/listofadrs.php
df = pd.read_csv("List of ADRs.csv")

# %%
# Filter for ADRs which have non-overlapping market hours, and those that we have IB data for
df = df.dropna(subset = ["Underlying Exchange"])
df = df[df["Country"].isin(["Australia", "China", "Japan", "India"])]
df = df[~df["Underlying Exchange"].isin(["London Stock Exchange"])]
# Further filter for those that we can find on IB manually
df = df[~df["Symbol"].isin(["BHP", "BNTC", "LFC", "SNP", "PTR", "ZNH", "CEA", "ACH", "SHI", "SNE"])]

# %%
df.to_csv("Asian_ADRs.csv")

# %%
df
# Out:
#     Symbol                                        Name    Country  \
# 16     WBK                   Westpac Banking Corp ADRs  Australia
# 18     JHX                James Hardie Industries ADRs  Australia
# 19    MESO                              Mesoblast ADRs  Australia
# 20     PLL               Piedmont Lithium Limited ADRs  Australia
# 22    IMMP                        Immutep Limited ADRs  Australia
# 23    KZIA                     Kazia Therapeutics ADRs  Australia
# 24    GENE                   Genetic Technologies ADRs  Australia
# 25    ATHE          Alterity Therapeutics Limited ADRs  Australia
# 26    IMRN                        Immuron Limited ADRs  Australia
# 83    BGNE                                BeiGene ADRs      China
# 133    HNP        Huaneng Power International Inc ADRs      China
# 269    HDB                          HDFC Bank Ltd ADRs      India
# 270   INFY                            Infosys Ltd ADRs      India
# 271    IBN                         ICICI Bank Ltd ADRs      India
# 272    WIT                              Wipro Ltd ADRs      India
# 273    TTM                        Tata Motors Ltd ADRs      India
# 274   VEDL                            Vedanta Ltd ADRs      India
# 275    RDY                Dr. Reddys Laboratories ADRs      India
# 307     TM                      Toyota Motor Corp ADRs      Japan
# 308   SONY                 Sony Group Corporation ADRs      Japan
# 310   MUFG    Mitsubishi UFJ Financial Group Inc. ADRs      Japan
# 311    TAK  Takeda Pharmaceutical Company Limited ADRs      Japan
# 312    HMC                     Honda Motor Co Ltd ADRs      Japan
# 313   SMFG    Sumitomo Mitsui Financial Group Inc ADRs      Japan
# 314    MFG             Mizuho Financial Group Inc ADRs      Japan
# 315    CAJ                              Canon Inc ADRs      Japan
# 316     IX                                   Orix ADRs      Japan
# 317    NMR                    Nomura Holdings Inc ADRs      Japan
#
#     Underlying Symbol               Underlying Exchange  \
# 16             AT:WBC                 Asx - All Markets
# 18             AT:JHX                 Asx - All Markets
# 19             AT:MSB                 Asx - All Markets
# 20             AT:PLL                 Asx - All Markets
# 22             AT:IMM                 Asx - All Markets
# 23             AT:KZA                 Asx - All Markets
# 24             AT:GTG                 Asx - All Markets
# 25             AT:PBT                 Asx - All Markets
# 26             AT:IMC                 Asx - All Markets
# 83            HK:6160                Hong Kong Exchange
# 133           HK:0902                Hong Kong Exchange
# 269       IS:HDFCBANK  National Stock Exchange Of India
# 270           IS:INFY  National Stock Exchange Of India
# 271      IS:ICICIBANK  National Stock Exchange Of India
# 272          IS:WIPRO  National Stock Exchange Of India
# 273     IS:TATAMOTORS  National Stock Exchange Of India
# 274           IS:VEDL  National Stock Exchange Of India
# 275        IS:DRREDDY  National Stock Exchange Of India
# 307           JT:7203              Tokyo Stock Exchange
# 308           JT:6758              Tokyo Stock Exchange
# 310           JT:8306              Tokyo Stock Exchange
# 311           JT:4502              Tokyo Stock Exchange
# 312           JT:7267              Tokyo Stock Exchange
# 313           JT:8316              Tokyo Stock Exchange
# 314           JT:8411              Tokyo Stock Exchange
# 315           JT:7751              Tokyo Stock Exchange
# 316           JT:8591              Tokyo Stock Exchange
# 317           JT:8604              Tokyo Stock Exchange
#
#                 GICS Sector        Market cap      P/E       P/S    P/B  \
# 16               Financials   $69,776,616,188    39.04     20.85   1.03
# 18                Materials   $14,421,616,850    84.29      5.29  11.29
# 19              Health Care    $1,071,645,908   -10.92     65.15   2.07
# 20                Materials    $1,047,422,124  -602.67      0.00  13.11
# 22              Health Care      $210,448,464     0.00     21.19   3.47
# 23              Health Care      $158,070,642     0.00  4,883.81   4.99
# 24              Health Care       $64,920,433     0.00  6,623.62   4.99
# 25              Health Care       $50,363,736     0.00  1,427.09   1.47
# 26              Health Care       $34,086,990     0.00     13.94   1.19
# 83              Health Care   $30,307,669,800   -18.98     98.12   7.83
# 133               Utilities    $1,667,461,025    13.10      0.05   0.01
# 269              Financials  $139,172,569,736   198.25     11.22   0.07
# 270  Information Technology   $82,514,030,521    32.93      6.13   8.42
# 271              Financials   $54,725,526,140    26.19      3.59   0.04
# 272  Information Technology   $35,831,101,871    27.12      4.28   0.07
# 273  Consumer Discretionary   $13,898,808,304    10.68      0.43   2.49
# 274               Materials   $11,895,029,248    10.03      1.04   0.02
# 275             Health Care   $10,329,636,438    35.70      3.96   0.06
# 307  Consumer Discretionary  $253,502,275,153    15.71      1.05   0.01
# 308  Consumer Discretionary  $140,469,337,616    13.52      1.72   0.03
# 310              Financials   $75,244,252,965    24.51      2.27   0.00
# 311             Health Care   $57,380,010,251    34.87      1.97   0.01
# 312  Consumer Discretionary   $55,121,767,125    13.89      0.47   0.01
# 313              Financials   $50,532,713,261   157.20      1.78   0.00
# 314              Financials   $37,834,823,430    10.34      1.72   0.00
# 315  Information Technology   $31,103,363,980    32.24      1.10   0.01
# 316              Financials   $21,942,173,976    11.61      1.22   0.01
# 317              Financials   $17,655,251,801     6.87      1.40   0.01
#
#     Current yield Avg Volume   Action
# 16          1.24%    107,977  Analyze
# 18          0.00%     28,094  Analyze
# 19          0.00%    189,714  Analyze
# 20          0.00%  1,476,404  Analyze
# 22          0.00%  6,207,627  Analyze
# 23          0.00%    131,442  Analyze
# 24          0.00%    552,907  Analyze
# 25          0.00%    294,308  Analyze
# 26          0.00%     22,810  Analyze
# 83          0.00%    300,259  Analyze
# 133         5.46%     50,612  Analyze
# 269         0.24%  1,405,480  Analyze
# 270         1.48%  7,989,302  Analyze
# 271         0.14%  5,970,955  Analyze
# 272         0.21%  1,778,212  Analyze
# 273         1.43%  1,289,346  Analyze
# 274         3.98%  1,036,700  Analyze
# 275         0.54%    185,803  Analyze
# 307         1.30%    387,349  Analyze
# 308         0.21%    928,903  Analyze
# 310         2.16%  2,117,632  Analyze
# 311         2.37%  2,683,026  Analyze
# 312         1.71%    820,228  Analyze
# 313         2.48%  1,587,673  Analyze
# 314         2.41%    340,802  Analyze
# 315         3.13%    228,541  Analyze
# 316         0.82%     24,818  Analyze
# 317         3.50%    773,832  Analyze

# %%
# Do we have data for both ADR and Stock
# 15      BHP - No
# 16      WBK - Yes
# 18      JHX - Yes
# 19     MESO - Yes
# 20      PLL - Yes
# 22     IMMP - Yes
# 23     KZIA - Yes
# 24     GENE - Yes
# 25     ATHE - Yes
# 26     IMRN - Yes
# 27     BNTC - No
# 83     BGNE - Yes
# 92      LFC - No?
# 94      SNP - No?
# 102     PTR - No?
# 119     ZNH - No?
# 125     CEA - No?
# 132     ACH - No?
# 133     HNP - Yes
# 150     SHI - No?
# 269     HDB - Yes
# 270    INFY - Yes
# 271     IBN - Yes
# 272     WIT - Yes
# 273     TTM - Yes
# 274    VEDL - Yes
# 275     RDY - Yes
# 307      TM - Yes
# 308    SONY - Yes
# 309     SNE - No
# 310    MUFG - Yes
# 311     TAK - Yes
# 312     HMC - Yes
# 313    SMFG - Yes
# 314     MFG - Yes
# 315     CAJ - Yes
# 316      IX - Yes
# 317     NMR - Yes
