# %%
from ib_insync import *
util.startLoop()

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=15)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=15>

# %%
from ib_insync import *
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import math
import datetime 
import statsmodels.formula.api as smf 
from datetime import date, time, datetime, timedelta
import seaborn as sns
import random
from ta import add_all_ta_features
from ta.utils import dropna
from ta.trend import *

# %%
#define a function to get IB data. endDate is the last date of the historical data 

def get_data(contract, history, freq, side, endDate =''):
    bar = ib.reqHistoricalData(
        contract,
        endDateTime = endDate,
        durationStr=history,
        barSizeSetting= freq,
        whatToShow=side,
        useRTH=True,
        formatDate=1)
    return util.df(bar)

history = '6 Y'
freq = '1 day'
side ='Trades'

# %%
adr_symbol = "TM"
adr_exchange = 'SMART'
adr_currency = "USD"

underlying_symbol = '7203'
underlying_exchange = 'TSEJ'
underlying_currency = 'JPY'

folder_name = "Japan/TM_7203/"

# %%
adr_contract = Contract(symbol = adr_symbol, secType = 'STK', exchange = adr_exchange, currency = adr_currency)
ib.qualifyContracts(adr_contract)
adr_df = get_data(adr_contract, history, freq, side)
print(adr_df.head(3))
adr_df.to_csv(folder_name + "adr.csv")
# Out:
#          date    open    high     low   close  volume   average  barCount
# 0  2015-04-09  139.10  140.13  139.00  139.91    2173  139.5200      1680
# 1  2015-04-10  138.71  139.82  138.66  139.65    2633  139.2250      2060
# 2  2015-04-13  137.67  138.00  137.20  137.56    2466  137.5555      1773

# %%
underlying_contract = Contract(symbol = underlying_symbol, secType = 'STK', exchange = underlying_exchange, currency = underlying_currency)
ib.qualifyContracts(underlying_contract)
underlying_df = get_data(underlying_contract, history, freq, side)
print(underlying_df.head(3))
underlying_df.to_csv(folder_name + "underlying.csv")
# Out:
#          date    open    high     low   close   volume  average  barCount
# 0  2015-04-10  8386.0  8410.0  8322.0  8326.0  7051800  8360.94     12307
# 1  2015-04-13  8326.0  8350.0  8203.0  8248.0  6695800  8248.70     13114
# 2  2015-04-14  8216.0  8296.0  8210.0  8285.0  4276300  8263.02      8930

# %%
pd.read_csv("Asian_ADRs.csv")
# Out:
#     Unnamed: 0 Symbol                                        Name    Country  \
# 0           16    WBK                   Westpac Banking Corp ADRs  Australia
# 1           18    JHX                James Hardie Industries ADRs  Australia
# 2           19   MESO                              Mesoblast ADRs  Australia
# 3           20    PLL               Piedmont Lithium Limited ADRs  Australia
# 4           22   IMMP                        Immutep Limited ADRs  Australia
# 5           23   KZIA                     Kazia Therapeutics ADRs  Australia
# 6           24   GENE                   Genetic Technologies ADRs  Australia
# 7           25   ATHE          Alterity Therapeutics Limited ADRs  Australia
# 8           26   IMRN                        Immuron Limited ADRs  Australia
# 9           83   BGNE                                BeiGene ADRs      China
# 10         133    HNP        Huaneng Power International Inc ADRs      China
# 11         269    HDB                          HDFC Bank Ltd ADRs      India
# 12         270   INFY                            Infosys Ltd ADRs      India
# 13         271    IBN                         ICICI Bank Ltd ADRs      India
# 14         272    WIT                              Wipro Ltd ADRs      India
# 15         273    TTM                        Tata Motors Ltd ADRs      India
# 16         274   VEDL                            Vedanta Ltd ADRs      India
# 17         275    RDY                Dr. Reddys Laboratories ADRs      India
# 18         307     TM                      Toyota Motor Corp ADRs      Japan
# 19         308   SONY                 Sony Group Corporation ADRs      Japan
# 20         310   MUFG    Mitsubishi UFJ Financial Group Inc. ADRs      Japan
# 21         311    TAK  Takeda Pharmaceutical Company Limited ADRs      Japan
# 22         312    HMC                     Honda Motor Co Ltd ADRs      Japan
# 23         313   SMFG    Sumitomo Mitsui Financial Group Inc ADRs      Japan
# 24         314    MFG             Mizuho Financial Group Inc ADRs      Japan
# 25         315    CAJ                              Canon Inc ADRs      Japan
# 26         316     IX                                   Orix ADRs      Japan
# 27         317    NMR                    Nomura Holdings Inc ADRs      Japan
#
#    Underlying Symbol               Underlying Exchange  \
# 0             AT:WBC                 Asx - All Markets
# 1             AT:JHX                 Asx - All Markets
# 2             AT:MSB                 Asx - All Markets
# 3             AT:PLL                 Asx - All Markets
# 4             AT:IMM                 Asx - All Markets
# 5             AT:KZA                 Asx - All Markets
# 6             AT:GTG                 Asx - All Markets
# 7             AT:PBT                 Asx - All Markets
# 8             AT:IMC                 Asx - All Markets
# 9            HK:6160                Hong Kong Exchange
# 10           HK:0902                Hong Kong Exchange
# 11       IS:HDFCBANK  National Stock Exchange Of India
# 12           IS:INFY  National Stock Exchange Of India
# 13      IS:ICICIBANK  National Stock Exchange Of India
# 14          IS:WIPRO  National Stock Exchange Of India
# 15     IS:TATAMOTORS  National Stock Exchange Of India
# 16           IS:VEDL  National Stock Exchange Of India
# 17        IS:DRREDDY  National Stock Exchange Of India
# 18           JT:7203              Tokyo Stock Exchange
# 19           JT:6758              Tokyo Stock Exchange
# 20           JT:8306              Tokyo Stock Exchange
# 21           JT:4502              Tokyo Stock Exchange
# 22           JT:7267              Tokyo Stock Exchange
# 23           JT:8316              Tokyo Stock Exchange
# 24           JT:8411              Tokyo Stock Exchange
# 25           JT:7751              Tokyo Stock Exchange
# 26           JT:8591              Tokyo Stock Exchange
# 27           JT:8604              Tokyo Stock Exchange
#
#                GICS Sector        Market cap     P/E       P/S    P/B  \
# 0               Financials   $69,776,616,188   39.04     20.85   1.03
# 1                Materials   $14,421,616,850   84.29      5.29  11.29
# 2              Health Care    $1,071,645,908  -10.92     65.15   2.07
# 3                Materials    $1,047,422,124 -602.67      0.00  13.11
# 4              Health Care      $210,448,464    0.00     21.19   3.47
# 5              Health Care      $158,070,642    0.00  4,883.81   4.99
# 6              Health Care       $64,920,433    0.00  6,623.62   4.99
# 7              Health Care       $50,363,736    0.00  1,427.09   1.47
# 8              Health Care       $34,086,990    0.00     13.94   1.19
# 9              Health Care   $30,307,669,800  -18.98     98.12   7.83
# 10               Utilities    $1,667,461,025   13.10      0.05   0.01
# 11              Financials  $139,172,569,736  198.25     11.22   0.07
# 12  Information Technology   $82,514,030,521   32.93      6.13   8.42
# 13              Financials   $54,725,526,140   26.19      3.59   0.04
# 14  Information Technology   $35,831,101,871   27.12      4.28   0.07
# 15  Consumer Discretionary   $13,898,808,304   10.68      0.43   2.49
# 16               Materials   $11,895,029,248   10.03      1.04   0.02
# 17             Health Care   $10,329,636,438   35.70      3.96   0.06
# 18  Consumer Discretionary  $253,502,275,153   15.71      1.05   0.01
# 19  Consumer Discretionary  $140,469,337,616   13.52      1.72   0.03
# 20              Financials   $75,244,252,965   24.51      2.27   0.00
# 21             Health Care   $57,380,010,251   34.87      1.97   0.01
# 22  Consumer Discretionary   $55,121,767,125   13.89      0.47   0.01
# 23              Financials   $50,532,713,261  157.20      1.78   0.00
# 24              Financials   $37,834,823,430   10.34      1.72   0.00
# 25  Information Technology   $31,103,363,980   32.24      1.10   0.01
# 26              Financials   $21,942,173,976   11.61      1.22   0.01
# 27              Financials   $17,655,251,801    6.87      1.40   0.01
#
#    Current yield Avg Volume   Action
# 0          1.24%    107,977  Analyze
# 1          0.00%     28,094  Analyze
# 2          0.00%    189,714  Analyze
# 3          0.00%  1,476,404  Analyze
# 4          0.00%  6,207,627  Analyze
# 5          0.00%    131,442  Analyze
# 6          0.00%    552,907  Analyze
# 7          0.00%    294,308  Analyze
# 8          0.00%     22,810  Analyze
# 9          0.00%    300,259  Analyze
# 10         5.46%     50,612  Analyze
# 11         0.24%  1,405,480  Analyze
# 12         1.48%  7,989,302  Analyze
# 13         0.14%  5,970,955  Analyze
# 14         0.21%  1,778,212  Analyze
# 15         1.43%  1,289,346  Analyze
# 16         3.98%  1,036,700  Analyze
# 17         0.54%    185,803  Analyze
# 18         1.30%    387,349  Analyze
# 19         0.21%    928,903  Analyze
# 20         2.16%  2,117,632  Analyze
# 21         2.37%  2,683,026  Analyze
# 22         1.71%    820,228  Analyze
# 23         2.48%  1,587,673  Analyze
# 24         2.41%    340,802  Analyze
# 25         3.13%    228,541  Analyze
# 26         0.82%     24,818  Analyze
# 27         3.50%    773,832  Analyze
